# %%
import pandas as pd

# %%
data = pd.read_csv('/Users/macbookpro/Downloads/Housing_New_York_Units_by_Building.csv')

# %%
data.columns
# Out:
# Index(['Project ID', 'Project Name', 'Project Start Date',
#        'Project Completion Date', 'Building ID', 'Number', 'Street', 'Borough',
#        'Postcode', 'BBL', 'BIN', 'Community Board', 'Council District',
#        'Census Tract', 'NTA - Neighborhood Tabulation Area', 'Latitude',
#        'Longitude', 'Latitude (Internal)', 'Longitude (Internal)',
#        'Building Completion Date', 'Reporting Construction Type',
#        'Extended Affordability Only', 'Prevailing Wage Status',
#        'Extremely Low Income Units', 'Very Low Income Units',
#        'Low Income Units', 'Moderate Income Units', 'Middle Income Units',
#        'Other Income Units', 'Studio Units', '1-BR Units', '2-BR Units',
#        '3-BR Units', '4-BR Units', '5-BR Units', '6-BR+ Units',
#        'Unknown-BR Units', 'Counted Rental Units',
#        'Counted Homeownership Units', 'All Counted Units', 'Total Units'],
#       dtype='object')

# %%
data
# Out:
#       Project ID                                  Project Name  \
# 0          61875                    1199 HOUSING CORP.PLP.FY19
# 1          61875                    1199 HOUSING CORP.PLP.FY19
# 2          61875                    1199 HOUSING CORP.PLP.FY19
# 3          61875                    1199 HOUSING CORP.PLP.FY19
# 4          62299          DUNN. 82-41 PARSONS BLVD. T BUILDING
# 5          65349                             BPR HDFC.HPO.FY19
# 6          65349                             BPR HDFC.HPO.FY19
# 7          65378     JENKINS PORTFOLIO COMPANIES LLC.YR15.FY19
# 8          65378     JENKINS PORTFOLIO COMPANIES LLC.YR15.FY19
# 9          65378     JENKINS PORTFOLIO COMPANIES LLC.YR15.FY19
# 10         65378     JENKINS PORTFOLIO COMPANIES LLC.YR15.FY19
# 11         65378     JENKINS PORTFOLIO COMPANIES LLC.YR15.FY19
# 12         65378     JENKINS PORTFOLIO COMPANIES LLC.YR15.FY19
# 13         65378     JENKINS PORTFOLIO COMPANIES LLC.YR15.FY19
# ...

# %%
data[data.isin(pd.DatetimeIndex[data['']])]

# %%
data['year'] = pd.DatetimeIndex(data['Project Start Date']).year
data = data

# %%
datax = data.groupby(['Borough', 'Project Completion Date']).size().to_frame('count_incidents').reset_index()
# data.groupby('[]')

# %%
pd.data
# Out:
#             Borough Project Completion Date  count_incidents
# 0             Bronx              01/01/2015                1
# 1             Bronx              01/08/2015                1
# 2             Bronx              01/08/2018                1
# 3             Bronx              01/09/2015                2
# 4             Bronx              01/09/2019                2
# 5             Bronx              01/11/2018                3
# 6             Bronx              01/12/2017                1
# 7             Bronx              01/12/2018                1
# 8             Bronx              01/15/2014                1
# 9             Bronx              01/19/2018                1
# 10            Bronx              01/20/2015                1
# 11            Bronx              01/20/2016                1
# 12            Bronx              01/20/2017                4
# 13            Bronx              01/21/2015                1
# ...

# %%
# data.groupby(['Borough', 'Project Start Date']).size()..

# %%
data['year'].min()
# Out:
# 2014

# %%
import matplotlib.pyplot as plt
# plot data
fig, ax = plt.subplots(figsize=(15,7))
# use unstack()
datax.groupby(['Project Completion Date','Borough']).count()['count_incidents'].unstack().plot(ax=ax)
# datax.groupby(['Project Completion Date','Borough']).count()['count_incidents'].plot(ax=ax)
